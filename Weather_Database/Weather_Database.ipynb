# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

## Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# # Loop through all the cities in our list.
# for i in range(len(cities)):
    
#     # Group cities in sets of 50 for logging purposes.
#     if(i % 50 == 0 and i>= 50):
#         set_count += 1
#         record_count = 1
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in our list.
#for i, item in enumerate(list):
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")  
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping ....")
        pass
        
    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | chiredzi
# Processing Record 3 of Set 1 | conroe
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | vao
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | bathsheba
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping ....
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | tabou
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | broome
# Processing Record 14 of Set 1 | zhuhai
# Processing Record 15 of Set 1 | yatou
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | puerto madero
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | kieta
# Processing Record 22 of Set 1 | kibala
# Processing Record 23 of Set 1 | kamenka
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | stantsiya gorchakovo
# City not found. Skipping ....
# Processing Record 26 of Set 1 | nanortalik
# Processing Record 27 of Set 1 | honningsvag
# Processing Record 28 of Set 1 | umm lajj
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | bengkulu
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | bandarbeyla
# Processing Record 35 of Set 1 | ramshir
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | itarema
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | pudem
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | binga
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | isla mujeres
# Processing Record 48 of Set 1 | paamiut
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping ....
# Processing Record 2 of Set 2 | kroya
# Processing Record 3 of Set 2 | helong
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping ....
# Processing Record 6 of Set 2 | lagos
# Processing Record 7 of Set 2 | pangkalanbuun
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | barinas
# Processing Record 10 of Set 2 | veraval
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | alice springs
# Processing Record 15 of Set 2 | kuruman
# Processing Record 16 of Set 2 | malartic
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | gualeguaychu
# Processing Record 19 of Set 2 | samusu
# City not found. Skipping ....
# Processing Record 20 of Set 2 | isangel
# Processing Record 21 of Set 2 | berdigestyakh
# Processing Record 22 of Set 2 | kurakh
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping ....
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | ituni
# City not found. Skipping ....
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | real
# Processing Record 29 of Set 2 | neiafu
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | marv dasht
# City not found. Skipping ....
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | merrill
# Processing Record 35 of Set 2 | haverfordwest
# Processing Record 36 of Set 2 | kapit
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | byron bay
# Processing Record 39 of Set 2 | muzhi
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | havre-saint-pierre
# Processing Record 42 of Set 2 | pafos
# Processing Record 43 of Set 2 | narsaq
# Processing Record 44 of Set 2 | noumea
# Processing Record 45 of Set 2 | santa cruz
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | doiwala
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | erdenet
# Processing Record 1 of Set 3 | eyl
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | pontes e lacerda
# Processing Record 4 of Set 3 | vestmanna
# Processing Record 5 of Set 3 | suntar
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | damietta
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | el silencio
# Processing Record 10 of Set 3 | attawapiskat
# City not found. Skipping ....
# Processing Record 11 of Set 3 | iquitos
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping ....
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | baykit
# Processing Record 16 of Set 3 | olafsvik
# Processing Record 17 of Set 3 | belozerskoye
# Processing Record 18 of Set 3 | constantine
# Processing Record 19 of Set 3 | coquimbo
# Processing Record 20 of Set 3 | dinsor
# City not found. Skipping ....
# Processing Record 21 of Set 3 | jiaojiang
# Processing Record 22 of Set 3 | avera
# Processing Record 23 of Set 3 | mangalam
# Processing Record 24 of Set 3 | teacapan
# Processing Record 25 of Set 3 | malanje
# Processing Record 26 of Set 3 | new norfolk
# Processing Record 27 of Set 3 | coihaique
# Processing Record 28 of Set 3 | kashan
# Processing Record 29 of Set 3 | banda aceh
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | aurad
# Processing Record 32 of Set 3 | arica
# Processing Record 33 of Set 3 | port-gentil
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping ....
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | huazolotitlan
# City not found. Skipping ....
# Processing Record 38 of Set 3 | lorengau
# Processing Record 39 of Set 3 | asau
# Processing Record 40 of Set 3 | pouebo
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | padang
# Processing Record 43 of Set 3 | cayeli
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | vardo
# Processing Record 46 of Set 3 | waipawa
# Processing Record 47 of Set 3 | tasiilaq
# Processing Record 48 of Set 3 | sines
# Processing Record 49 of Set 3 | lasa
# Processing Record 50 of Set 3 | vestmannaeyjar
# Processing Record 1 of Set 4 | tandur
# Processing Record 2 of Set 4 | nargana
# Processing Record 3 of Set 4 | husavik
# Processing Record 4 of Set 4 | sabang
# Processing Record 5 of Set 4 | moyale
# Processing Record 6 of Set 4 | gweta
# Processing Record 7 of Set 4 | georgetown
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | turukhansk
# Processing Record 10 of Set 4 | labuhan
# Processing Record 11 of Set 4 | srednekolymsk
# Processing Record 12 of Set 4 | tukrah
# Processing Record 13 of Set 4 | polunochnoye
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | coromandel
# Processing Record 16 of Set 4 | yar-sale
# Processing Record 17 of Set 4 | camacha
# Processing Record 18 of Set 4 | mikhaylovka
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping ....
# Processing Record 20 of Set 4 | seryshevo
# Processing Record 21 of Set 4 | edd
# Processing Record 22 of Set 4 | nome
# Processing Record 23 of Set 4 | airai
# Processing Record 24 of Set 4 | xiaoweizhai
# Processing Record 25 of Set 4 | zaysan
# Processing Record 26 of Set 4 | candido de abreu
# Processing Record 27 of Set 4 | carutapera
# Processing Record 28 of Set 4 | kaitangata
# Processing Record 29 of Set 4 | sao gabriel
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | lincoln
# Processing Record 32 of Set 4 | floriano
# Processing Record 33 of Set 4 | yukamenskoye
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | hobart
# Processing Record 36 of Set 4 | san cristobal
# Processing Record 37 of Set 4 | vanimo
# Processing Record 38 of Set 4 | saint-felicien
# Processing Record 39 of Set 4 | andenes
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | acajutla
# Processing Record 42 of Set 4 | saskylakh
# Processing Record 43 of Set 4 | grand-santi
# Processing Record 44 of Set 4 | poum
# Processing Record 45 of Set 4 | asosa
# Processing Record 46 of Set 4 | sibolga
# Processing Record 47 of Set 4 | bilibino
# Processing Record 48 of Set 4 | griffith
# Processing Record 49 of Set 4 | meulaboh
# Processing Record 50 of Set 4 | yulara
# Processing Record 1 of Set 5 | prachuap khiri khan
# Processing Record 2 of Set 5 | burica
# City not found. Skipping ....
# Processing Record 3 of Set 5 | beloha
# Processing Record 4 of Set 5 | los llanos de aridane
# Processing Record 5 of Set 5 | sergeyevka
# Processing Record 6 of Set 5 | ribeira grande
# Processing Record 7 of Set 5 | emilio carranza
# Processing Record 8 of Set 5 | saint anthony
# Processing Record 9 of Set 5 | diffa
# Processing Record 10 of Set 5 | barbosa ferraz
# Processing Record 11 of Set 5 | talnakh
# Processing Record 12 of Set 5 | paracatu
# Processing Record 13 of Set 5 | tabiauea
# City not found. Skipping ....
# Processing Record 14 of Set 5 | clinton
# Processing Record 15 of Set 5 | marabba
# Processing Record 16 of Set 5 | sarramea
# Processing Record 17 of Set 5 | mabaruma
# Processing Record 18 of Set 5 | kasempa
# Processing Record 19 of Set 5 | kurumkan
# Processing Record 20 of Set 5 | tilichiki
# Processing Record 21 of Set 5 | provideniya
# Processing Record 22 of Set 5 | nelson bay
# Processing Record 23 of Set 5 | dawei
# Processing Record 24 of Set 5 | flin flon
# Processing Record 25 of Set 5 | stolin
# Processing Record 26 of Set 5 | praia
# Processing Record 27 of Set 5 | kulu
# Processing Record 28 of Set 5 | matara
# Processing Record 29 of Set 5 | kostomuksha
# Processing Record 30 of Set 5 | wasilla
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | merauke
# Processing Record 33 of Set 5 | bambous virieux
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | tambovka
# Processing Record 36 of Set 5 | dingle
# Processing Record 37 of Set 5 | shanghai
# Processing Record 38 of Set 5 | batemans bay
# Processing Record 39 of Set 5 | igboho
# Processing Record 40 of Set 5 | falmouth
# Processing Record 41 of Set 5 | lodeynoye pole
# Processing Record 42 of Set 5 | buraydah
# Processing Record 43 of Set 5 | portland
# Processing Record 44 of Set 5 | zhigansk
# Processing Record 45 of Set 5 | kamina
# Processing Record 46 of Set 5 | namibe
# Processing Record 47 of Set 5 | tumannyy
# City not found. Skipping ....
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | bobcaygeon
# Processing Record 50 of Set 5 | morondava
# Processing Record 1 of Set 6 | nizhneyansk
# City not found. Skipping ....
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | khatanga
# Processing Record 4 of Set 6 | mantes-la-ville
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | kisesa
# Processing Record 7 of Set 6 | codrington
# Processing Record 8 of Set 6 | plouzane
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | luanda
# Processing Record 11 of Set 6 | antigonish
# Processing Record 12 of Set 6 | inta
# Processing Record 13 of Set 6 | jiaozuo
# Processing Record 14 of Set 6 | tocantinopolis
# City not found. Skipping ....
# Processing Record 15 of Set 6 | izhma
# Processing Record 16 of Set 6 | susanville
# Processing Record 17 of Set 6 | baculin
# Processing Record 18 of Set 6 | norman wells
# Processing Record 19 of Set 6 | tezu
# Processing Record 20 of Set 6 | mana
# Processing Record 21 of Set 6 | north bend
# Processing Record 22 of Set 6 | lima
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | lira
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | astoria
# Processing Record 28 of Set 6 | dudinka
# Processing Record 29 of Set 6 | dunedin
# Processing Record 30 of Set 6 | ejido
# Processing Record 31 of Set 6 | necochea
# Processing Record 32 of Set 6 | victoria
# Processing Record 33 of Set 6 | yairipok
# Processing Record 34 of Set 6 | chuy
# Processing Record 35 of Set 6 | atambua
# Processing Record 36 of Set 6 | shingu
# Processing Record 37 of Set 6 | sisimiut
# Processing Record 38 of Set 6 | odweyne
# Processing Record 39 of Set 6 | geraldton
# Processing Record 40 of Set 6 | batticaloa
# Processing Record 41 of Set 6 | mezen
# Processing Record 42 of Set 6 | kampot
# Processing Record 43 of Set 6 | natal
# Processing Record 44 of Set 6 | santa fe
# Processing Record 45 of Set 6 | serowe
# Processing Record 46 of Set 6 | humaita
# Processing Record 47 of Set 6 | salalah
# Processing Record 48 of Set 6 | ranong
# Processing Record 49 of Set 6 | fortuna
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 1 of Set 7 | grand gaube
# Processing Record 2 of Set 7 | umm kaddadah
# Processing Record 3 of Set 7 | hofn
# Processing Record 4 of Set 7 | kadykchan
# City not found. Skipping ....
# Processing Record 5 of Set 7 | palabuhanratu
# City not found. Skipping ....
# Processing Record 6 of Set 7 | touros
# Processing Record 7 of Set 7 | omboue
# Processing Record 8 of Set 7 | temaraia
# City not found. Skipping ....
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | elizabeth city
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | lata
# Processing Record 13 of Set 7 | khonuu
# City not found. Skipping ....
# Processing Record 14 of Set 7 | tsihombe
# City not found. Skipping ....
# Processing Record 15 of Set 7 | fevralsk
# City not found. Skipping ....
# Processing Record 16 of Set 7 | leh
# Processing Record 17 of Set 7 | marathon
# Processing Record 18 of Set 7 | kibaya
# Processing Record 19 of Set 7 | ostrovnoy
# Processing Record 20 of Set 7 | dhidhdhoo
# Processing Record 21 of Set 7 | olinda
# Processing Record 22 of Set 7 | galeana
# Processing Record 23 of Set 7 | paita
# Processing Record 24 of Set 7 | aykhal
# Processing Record 25 of Set 7 | narasannapeta
# Processing Record 26 of Set 7 | dharchula
# Processing Record 27 of Set 7 | shelburne
# Processing Record 28 of Set 7 | pontianak
# Processing Record 29 of Set 7 | baishishan
# Processing Record 30 of Set 7 | tawkar
# City not found. Skipping ....
# Processing Record 31 of Set 7 | ndjole
# Processing Record 32 of Set 7 | deputatskiy
# Processing Record 33 of Set 7 | caravelas
# Processing Record 34 of Set 7 | bulungu
# Processing Record 35 of Set 7 | yazman
# Processing Record 36 of Set 7 | talara
# Processing Record 37 of Set 7 | amderma
# City not found. Skipping ....
# Processing Record 38 of Set 7 | celarevo
# Processing Record 39 of Set 7 | fairbanks
# Processing Record 40 of Set 7 | makkaveyevo
# Processing Record 41 of Set 7 | cidreira
# Processing Record 42 of Set 7 | takoradi
# Processing Record 43 of Set 7 | palu
# Processing Record 44 of Set 7 | bennington
# Processing Record 45 of Set 7 | cap-aux-meules
# Processing Record 46 of Set 7 | makakilo city
# Processing Record 47 of Set 7 | rawson
# Processing Record 48 of Set 7 | nishihara
# Processing Record 49 of Set 7 | tavares
# Processing Record 50 of Set 7 | gat
# Processing Record 1 of Set 8 | linhares
# Processing Record 2 of Set 8 | sinnamary
# Processing Record 3 of Set 8 | saint-augustin
# Processing Record 4 of Set 8 | altay
# Processing Record 5 of Set 8 | chagda
# City not found. Skipping ....
# Processing Record 6 of Set 8 | port hardy
# Processing Record 7 of Set 8 | maneciu
# Processing Record 8 of Set 8 | sterling
# Processing Record 9 of Set 8 | kenai
# Processing Record 10 of Set 8 | grand centre
# City not found. Skipping ....
# Processing Record 11 of Set 8 | ust-maya
# Processing Record 12 of Set 8 | guerrero negro
# Processing Record 13 of Set 8 | vanavara
# Processing Record 14 of Set 8 | rio grande
# Processing Record 15 of Set 8 | asind
# Processing Record 16 of Set 8 | yenotayevka
# Processing Record 17 of Set 8 | port moresby
# Processing Record 18 of Set 8 | high prairie
# Processing Record 19 of Set 8 | binabalian
# Processing Record 20 of Set 8 | ko samui
# Processing Record 21 of Set 8 | katsiveli
# City not found. Skipping ....
# Processing Record 22 of Set 8 | junction city
# Processing Record 23 of Set 8 | bonavista
# Processing Record 24 of Set 8 | moose factory
# Processing Record 25 of Set 8 | wolkersdorf
# Processing Record 26 of Set 8 | kang
# Processing Record 27 of Set 8 | vung tau
# Processing Record 28 of Set 8 | bloemendaal
# Processing Record 29 of Set 8 | bara
# Processing Record 30 of Set 8 | araouane
# Processing Record 31 of Set 8 | hambantota
# Processing Record 32 of Set 8 | negotin
# Processing Record 33 of Set 8 | meadow lake
# Processing Record 34 of Set 8 | henties bay
# Processing Record 35 of Set 8 | areosa
# Processing Record 36 of Set 8 | chapais
# Processing Record 37 of Set 8 | dukat
# Processing Record 38 of Set 8 | vaitape
# Processing Record 39 of Set 8 | diamantino
# Processing Record 40 of Set 8 | laguna
# Processing Record 41 of Set 8 | jonava
# Processing Record 42 of Set 8 | ardakan
# Processing Record 43 of Set 8 | ponnani
# Processing Record 44 of Set 8 | jijiga
# Processing Record 45 of Set 8 | urumqi
# Processing Record 46 of Set 8 | verkhoyansk
# Processing Record 47 of Set 8 | tahe
# Processing Record 48 of Set 8 | huambo
# Processing Record 49 of Set 8 | kysyl-syr
# Processing Record 50 of Set 8 | port elizabeth
# Processing Record 1 of Set 9 | yumen
# Processing Record 2 of Set 9 | vilcun
# Processing Record 3 of Set 9 | saint-pierre
# Processing Record 4 of Set 9 | zaranj
# Processing Record 5 of Set 9 | lavrentiya
# Processing Record 6 of Set 9 | ucluelet
# Processing Record 7 of Set 9 | inverell
# Processing Record 8 of Set 9 | benguela
# Processing Record 9 of Set 9 | bom jesus
# Processing Record 10 of Set 9 | cockburn harbour
# City not found. Skipping ....
# Processing Record 11 of Set 9 | guirang
# Processing Record 12 of Set 9 | palmer
# Processing Record 13 of Set 9 | abalak
# Processing Record 14 of Set 9 | semirom
# Processing Record 15 of Set 9 | hemsedal
# Processing Record 16 of Set 9 | araxa
# Processing Record 17 of Set 9 | muros
# Processing Record 18 of Set 9 | baturyn
# Processing Record 19 of Set 9 | pacific grove
# Processing Record 20 of Set 9 | dzemul
# Processing Record 21 of Set 9 | cangucu
# Processing Record 22 of Set 9 | sassandra
# Processing Record 23 of Set 9 | waddan
# Processing Record 24 of Set 9 | arman
# Processing Record 25 of Set 9 | sioux lookout
# Processing Record 26 of Set 9 | klaksvik
# Processing Record 27 of Set 9 | makoshyne
# Processing Record 28 of Set 9 | jumla
# Processing Record 29 of Set 9 | uvat
# Processing Record 30 of Set 9 | whitianga
# Processing Record 31 of Set 9 | bursa
# Processing Record 32 of Set 9 | sorong
# Processing Record 33 of Set 9 | novopokrovka
# Processing Record 34 of Set 9 | araceli
# Processing Record 35 of Set 9 | kalmunai
# Processing Record 36 of Set 9 | xocali
# Processing Record 37 of Set 9 | lucea
# Processing Record 38 of Set 9 | aiquile
# Processing Record 39 of Set 9 | caborca
# Processing Record 40 of Set 9 | liwonde
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | jieshi
# Processing Record 43 of Set 9 | ruatoria
# City not found. Skipping ....
# Processing Record 44 of Set 9 | soissons
# Processing Record 45 of Set 9 | lafia
# Processing Record 46 of Set 9 | zambezi
# Processing Record 47 of Set 9 | brezno
# Processing Record 48 of Set 9 | churapcha
# Processing Record 49 of Set 9 | ginda
# Processing Record 50 of Set 9 | louisbourg
# City not found. Skipping ....
# Processing Record 1 of Set 10 | rosetta
# Processing Record 2 of Set 10 | harpalpur
# Processing Record 3 of Set 10 | mehamn
# Processing Record 4 of Set 10 | hualmay
# Processing Record 5 of Set 10 | nantucket
# Processing Record 6 of Set 10 | hammerfest
# Processing Record 7 of Set 10 | buta
# Processing Record 8 of Set 10 | terra santa
# Processing Record 9 of Set 10 | mys shmidta
# City not found. Skipping ....
# Processing Record 10 of Set 10 | uhlove
# Processing Record 11 of Set 10 | tahta
# Processing Record 12 of Set 10 | port blair
# Processing Record 13 of Set 10 | tapaua
# City not found. Skipping ....
# Processing Record 14 of Set 10 | hanstholm
# Processing Record 15 of Set 10 | gobabis
# Processing Record 16 of Set 10 | karlshamn
# Processing Record 17 of Set 10 | haines junction
# Processing Record 18 of Set 10 | richards bay
# Processing Record 19 of Set 10 | the pas
# Processing Record 20 of Set 10 | shimoda
# Processing Record 21 of Set 10 | camabatela
# Processing Record 22 of Set 10 | chincha alta
# Processing Record 23 of Set 10 | ubud
# Processing Record 24 of Set 10 | luderitz
# Processing Record 25 of Set 10 | constitucion
# Processing Record 26 of Set 10 | mitsamiouli
# Processing Record 27 of Set 10 | puerto escondido
# Processing Record 28 of Set 10 | mercedes
# Processing Record 29 of Set 10 | kuanshan
# City not found. Skipping ....
# Processing Record 30 of Set 10 | chokurdakh
# Processing Record 31 of Set 10 | dakar
# Processing Record 32 of Set 10 | saint-louis
# Processing Record 33 of Set 10 | karratha
# Processing Record 34 of Set 10 | ertil
# Processing Record 35 of Set 10 | burnie
# Processing Record 36 of Set 10 | labuan
# Processing Record 37 of Set 10 | mamallapuram
# Processing Record 38 of Set 10 | cayenne
# Processing Record 39 of Set 10 | aquiraz
# Processing Record 40 of Set 10 | berlevag
# Processing Record 41 of Set 10 | hirara
# Processing Record 42 of Set 10 | satitoa
# City not found. Skipping ....
# Processing Record 43 of Set 10 | molina
# Processing Record 44 of Set 10 | pingliang
# Processing Record 45 of Set 10 | hof
# Processing Record 46 of Set 10 | ongole
# Processing Record 47 of Set 10 | gamba
# Processing Record 48 of Set 10 | bac lieu
# Processing Record 49 of Set 10 | jardim
# Processing Record 50 of Set 10 | enid
# Processing Record 1 of Set 11 | alofi
# Processing Record 2 of Set 11 | jackson
# Processing Record 3 of Set 11 | caraballeda
# Processing Record 4 of Set 11 | maua
# Processing Record 5 of Set 11 | placido de castro
# Processing Record 6 of Set 11 | bani walid
# Processing Record 7 of Set 11 | dobson
# Processing Record 8 of Set 11 | santiago de cao
# Processing Record 9 of Set 11 | sitka
# Processing Record 10 of Set 11 | lagoa
# Processing Record 11 of Set 11 | trairi
# Processing Record 12 of Set 11 | fountain hills
# Processing Record 13 of Set 11 | turbat
# Processing Record 14 of Set 11 | ola
# Processing Record 15 of Set 11 | stephenville
# Processing Record 16 of Set 11 | jingdezhen
# Processing Record 17 of Set 11 | kupang
# Processing Record 18 of Set 11 | manadhoo
# Processing Record 19 of Set 11 | atar
# Processing Record 20 of Set 11 | verkh-chebula
# Processing Record 21 of Set 11 | gummidipundi
# Processing Record 22 of Set 11 | rawannawi
# City not found. Skipping ....
# Processing Record 23 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 11 | saleaula
# City not found. Skipping ....
# Processing Record 25 of Set 11 | plettenberg bay
# Processing Record 26 of Set 11 | quepos
# Processing Record 27 of Set 11 | arrecife
# Processing Record 28 of Set 11 | ngunguru
# Processing Record 29 of Set 11 | santa rosa
# Processing Record 30 of Set 11 | burns lake
# Processing Record 31 of Set 11 | mazyr
# Processing Record 32 of Set 11 | bubaque
# Processing Record 33 of Set 11 | lulea
# Processing Record 34 of Set 11 | pisco
# Processing Record 35 of Set 11 | lake jackson
# Processing Record 36 of Set 11 | saint-pierre-des-corps
# Processing Record 37 of Set 11 | kawalu
# Processing Record 38 of Set 11 | yanchukan
# City not found. Skipping ....
# Processing Record 39 of Set 11 | indramayu
# Processing Record 40 of Set 11 | quelimane
# Processing Record 41 of Set 11 | la ronge
# Processing Record 42 of Set 11 | oranjemund
# Processing Record 43 of Set 11 | ust-nera
# Processing Record 44 of Set 11 | camana
# Processing Record 45 of Set 11 | rincon
# Processing Record 46 of Set 11 | ipixuna
# Processing Record 47 of Set 11 | presidencia roque saenz pena
# Processing Record 48 of Set 11 | ampanihy
# Processing Record 49 of Set 11 | dunkwa
# Processing Record 50 of Set 11 | mareeba
# Processing Record 1 of Set 12 | chaiya
# Processing Record 2 of Set 12 | nalut
# Processing Record 3 of Set 12 | guangyuan
# Processing Record 4 of Set 12 | ziway
# Processing Record 5 of Set 12 | port lincoln
# Processing Record 6 of Set 12 | zhanakorgan
# Processing Record 7 of Set 12 | marcona
# City not found. Skipping ....
# Processing Record 8 of Set 12 | otane
# Processing Record 9 of Set 12 | lensk
# Processing Record 10 of Set 12 | sao jose da coroa grande
# Processing Record 11 of Set 12 | bayir
# Processing Record 12 of Set 12 | beringovskiy
# Processing Record 13 of Set 12 | ust-barguzin
# Processing Record 14 of Set 12 | college
# Processing Record 15 of Set 12 | tatawin
# Processing Record 16 of Set 12 | dipkarpaz
# City not found. Skipping ....
# Processing Record 17 of Set 12 | chateau-gontier
# Processing Record 18 of Set 12 | hami
# Processing Record 19 of Set 12 | adrar
# Processing Record 20 of Set 12 | madimba
# Processing Record 21 of Set 12 | aklavik
# Processing Record 22 of Set 12 | smoky lake
# Processing Record 23 of Set 12 | fort nelson
# Processing Record 24 of Set 12 | andra
# Processing Record 25 of Set 12 | huilong
# Processing Record 26 of Set 12 | boyolangu
# Processing Record 27 of Set 12 | saqqez
# Processing Record 28 of Set 12 | toamasina
# Processing Record 29 of Set 12 | divicani
# Processing Record 30 of Set 12 | corowa
# Processing Record 31 of Set 12 | ihosy
# Processing Record 32 of Set 12 | katha
# City not found. Skipping ....
# Processing Record 33 of Set 12 | las palmas
# Processing Record 34 of Set 12 | hamilton
# Processing Record 35 of Set 12 | mahibadhoo
# Processing Record 36 of Set 12 | tashtyp
# Processing Record 37 of Set 12 | maykain
# City not found. Skipping ....
# Processing Record 38 of Set 12 | kedrovyy
# Processing Record 39 of Set 12 | urdzhar
# City not found. Skipping ....
# Processing Record 40 of Set 12 | nevel
# Processing Record 41 of Set 12 | sur
# Processing Record 42 of Set 12 | kununurra
# Processing Record 43 of Set 12 | vila franca do campo
# Processing Record 44 of Set 12 | ponta do sol
# Processing Record 45 of Set 12 | acari
# Processing Record 46 of Set 12 | brae
# Processing Record 47 of Set 12 | najran
# Processing Record 48 of Set 12 | vavatenina
# Processing Record 49 of Set 12 | nueva concepcion
# Processing Record 50 of Set 12 | northam
# Processing Record 1 of Set 13 | beckley
# Processing Record 2 of Set 13 | kavaratti
# Processing Record 3 of Set 13 | marawi
# Processing Record 4 of Set 13 | baytown
# Processing Record 5 of Set 13 | mosquera
# Processing Record 6 of Set 13 | jeremie
# Processing Record 7 of Set 13 | kushima
# Processing Record 8 of Set 13 | mapimi
# Processing Record 9 of Set 13 | tabialan
# City not found. Skipping ....
# Processing Record 10 of Set 13 | ordzhonikidzevskiy
# Processing Record 11 of Set 13 | les cayes
# Processing Record 12 of Set 13 | gravelbourg
# Processing Record 13 of Set 13 | ureki
# Processing Record 14 of Set 13 | solnechnyy
# Processing Record 15 of Set 13 | ryotsu
# Processing Record 16 of Set 13 | muroto
# Processing Record 17 of Set 13 | kodinsk
# Processing Record 18 of Set 13 | sao miguel do araguaia
# Processing Record 19 of Set 13 | ponta delgada
# Processing Record 20 of Set 13 | flagstaff
# Processing Record 21 of Set 13 | songjianghe
# Processing Record 22 of Set 13 | udankudi
# Processing Record 23 of Set 13 | wicklow
# Processing Record 24 of Set 13 | payo
# Processing Record 25 of Set 13 | nanning
# Processing Record 26 of Set 13 | katherine
# Processing Record 27 of Set 13 | soskovo
# Processing Record 28 of Set 13 | awbari
# Processing Record 29 of Set 13 | bilma
# Processing Record 30 of Set 13 | columbia
# Processing Record 31 of Set 13 | vangaindrano
# Processing Record 32 of Set 13 | vila
# Processing Record 33 of Set 13 | san luis
# Processing Record 34 of Set 13 | bonthe
# Processing Record 35 of Set 13 | san andres
# Processing Record 36 of Set 13 | rochester
# Processing Record 37 of Set 13 | augustdorf
# Processing Record 38 of Set 13 | tshikapa
# Processing Record 39 of Set 13 | yerbogachen
# Processing Record 40 of Set 13 | hanna
# Processing Record 41 of Set 13 | longkou
# Processing Record 42 of Set 13 | tenochtitlan
# Processing Record 43 of Set 13 | terrak
# Processing Record 44 of Set 13 | smithers
# Processing Record 45 of Set 13 | severnyy
# Processing Record 46 of Set 13 | wenatchee
# Processing Record 47 of Set 13 | cabildo
# Processing Record 48 of Set 13 | faya
# Processing Record 49 of Set 13 | praia da vitoria
# Processing Record 50 of Set 13 | puerto baquerizo moreno
# Processing Record 1 of Set 14 | vinh
# Processing Record 2 of Set 14 | norfolk
# Processing Record 3 of Set 14 | daru
# Processing Record 4 of Set 14 | tawnat
# City not found. Skipping ....
# Processing Record 5 of Set 14 | bontang
# Processing Record 6 of Set 14 | bolungarvik
# City not found. Skipping ....
# Processing Record 7 of Set 14 | dickinson
# Processing Record 8 of Set 14 | martinsburg
# Processing Record 9 of Set 14 | rocha
# Processing Record 10 of Set 14 | asekeyevo
# Processing Record 11 of Set 14 | tyulgan
# Processing Record 12 of Set 14 | aromashevo
# Processing Record 13 of Set 14 | kaduna
# Processing Record 14 of Set 14 | port hueneme
# Processing Record 15 of Set 14 | pilao arcado
# City not found. Skipping ....
# Processing Record 16 of Set 14 | verkhniy avzyan
# Processing Record 17 of Set 14 | meyungs
# City not found. Skipping ....
# Processing Record 18 of Set 14 | umzimvubu
# City not found. Skipping ....
# Processing Record 19 of Set 14 | kandrian
# Processing Record 20 of Set 14 | mogwase
# Processing Record 21 of Set 14 | vastervik
# City not found. Skipping ....
# Processing Record 22 of Set 14 | hihifo
# City not found. Skipping ....
# Processing Record 23 of Set 14 | tommot
# Processing Record 24 of Set 14 | miandrivazo
# Processing Record 25 of Set 14 | ahmadpur
# Processing Record 26 of Set 14 | tigre
# Processing Record 27 of Set 14 | marzuq
# Processing Record 28 of Set 14 | eldikan
# City not found. Skipping ....
# Processing Record 29 of Set 14 | kirakira
# Processing Record 30 of Set 14 | virginia beach
# Processing Record 31 of Set 14 | harwich
# Processing Record 32 of Set 14 | sri aman
# Processing Record 33 of Set 14 | primorsk
# Processing Record 34 of Set 14 | mantua
# Processing Record 35 of Set 14 | te anau
# Processing Record 36 of Set 14 | kalabo
# Processing Record 37 of Set 14 | caernarfon
# Processing Record 38 of Set 14 | wanning
# Processing Record 39 of Set 14 | ayagoz
# Processing Record 40 of Set 14 | laizhou
# Processing Record 41 of Set 14 | bani
# Processing Record 42 of Set 14 | half moon bay
# Processing Record 43 of Set 14 | novikovo
# Processing Record 44 of Set 14 | balimo
# City not found. Skipping ....
# Processing Record 45 of Set 14 | general roca
# Processing Record 46 of Set 14 | guadalupe y calvo
# Processing Record 47 of Set 14 | muisne
# Processing Record 48 of Set 14 | kiama
# Processing Record 49 of Set 14 | great yarmouth
# Processing Record 50 of Set 14 | yinchuan
# Processing Record 1 of Set 15 | zarubino
# Processing Record 2 of Set 15 | issenye
# Processing Record 3 of Set 15 | wajir
# Processing Record 4 of Set 15 | rankovce
# Processing Record 5 of Set 15 | mildura
# Processing Record 6 of Set 15 | mackenzie
# Processing Record 7 of Set 15 | thinadhoo
# Processing Record 8 of Set 15 | jamalpur
# Processing Record 9 of Set 15 | lewiston
# Processing Record 10 of Set 15 | ayan
# Processing Record 11 of Set 15 | ternate
# Processing Record 12 of Set 15 | srikakulam
# Processing Record 13 of Set 15 | tiznit
# Processing Record 14 of Set 15 | samoded
# Processing Record 15 of Set 15 | yaguajay
# Processing Record 16 of Set 15 | ewa beach
# Processing Record 17 of Set 15 | hobyo
# Processing Record 18 of Set 15 | ashtian
# Processing Record 19 of Set 15 | harper
# Processing Record 20 of Set 15 | lar gerd
# City not found. Skipping ....
# Processing Record 21 of Set 15 | cabedelo
# Processing Record 22 of Set 15 | adre
# Processing Record 23 of Set 15 | berbera
# Processing Record 24 of Set 15 | santa maria
# Processing Record 25 of Set 15 | haibowan
# City not found. Skipping ....
# Processing Record 26 of Set 15 | maracaibo
# Processing Record 27 of Set 15 | lumberton
# Processing Record 28 of Set 15 | naze
# Processing Record 29 of Set 15 | tak
# Processing Record 30 of Set 15 | komsomolskiy
# Processing Record 31 of Set 15 | zhanatas
# City not found. Skipping ....
# Processing Record 32 of Set 15 | jawhar
# Processing Record 33 of Set 15 | itoman
# Processing Record 34 of Set 15 | rio gallegos
# Processing Record 35 of Set 15 | koksovyy
# Processing Record 36 of Set 15 | tarko-sale
# Processing Record 37 of Set 15 | simpang
# Processing Record 38 of Set 15 | yauya
# Processing Record 39 of Set 15 | inuvik
# Processing Record 40 of Set 15 | emba
# Processing Record 41 of Set 15 | kihei
# Processing Record 42 of Set 15 | guacimo
# Processing Record 43 of Set 15 | nabire
# Processing Record 44 of Set 15 | mpulungu
# Processing Record 45 of Set 15 | marsh harbour
# Processing Record 46 of Set 15 | baiyin
# Processing Record 47 of Set 15 | gracac
# Processing Record 48 of Set 15 | urusha
# Processing Record 49 of Set 15 | vodnyy
# Processing Record 50 of Set 15 | chernyshevskiy
# Processing Record 1 of Set 16 | alta floresta
# Processing Record 2 of Set 16 | alexandria
# Processing Record 3 of Set 16 | totness
# Processing Record 4 of Set 16 | coari
# Processing Record 5 of Set 16 | kismayo
# Processing Record 6 of Set 16 | korla
# Processing Record 7 of Set 16 | iberia
# Processing Record 8 of Set 16 | porto santo
# Processing Record 9 of Set 16 | porto novo
# Processing Record 10 of Set 16 | kita
# Processing Record 11 of Set 16 | springdale
# Processing Record 12 of Set 16 | portoferraio
# Processing Record 13 of Set 16 | ous
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Cape Town -33.9258   18.4232     59.11        69           1        7.34
# 1   Chiredzi -21.0500   31.6667     89.83        27           5        7.40
# 2     Conroe  30.3119  -95.4560     71.37        92          40        6.06
# 3  Carnarvon -24.8667  113.6333     78.87        61           0       16.11
# 4        Vao -22.6667  167.4833     72.23        75          12       14.58
#
#   Country Current Description
# 0      ZA           clear sky
# 1      ZW           clear sky
# 2      US    scattered clouds
# 3      AU           clear sky
# 4      NC          few clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cape Town      ZA -33.9258   18.4232     59.11        69           1
# 1   Chiredzi      ZW -21.0500   31.6667     89.83        27           5
# 2     Conroe      US  30.3119  -95.4560     71.37        92          40
# 3  Carnarvon      AU -24.8667  113.6333     78.87        61           0
# 4        Vao      NC -22.6667  167.4833     72.23        75          12
#
#    Wind Speed Current Description
# 0        7.34           clear sky
# 1        7.40           clear sky
# 2        6.06    scattered clouds
# 3       16.11           clear sky
# 4       14.58          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
